# %%
import requests

# results 2016
url = "https://en.wikipedia.org/wiki/2016_United_States_presidential_election#Results_by_state"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
import pandas as pd
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content)

# %%
table1= soup.find('div', style='overflow:auto')

# %%
# filtering all td tags to get state & percentages as list 

table_list1 = []
for td in table1.find_all('td'):
        table_list1.append(td.text.strip())

# %%
# indexing the elements

for index, element in enumerate(table_list1):
    index,element

# %%
# searching for elements with letters, group them into sublists with state name as first index (listname:states_data)
import re       

states_data = []
current_state = []

for element in table_list1:
    if re.search(r'[a-zA-Z]', element):  
        if current_state:
            states_data.append(current_state)
        current_state = [element]  
    else:
        current_state.append(element)
if current_state:
    states_data.append(current_state)

# %%
# filtering the list, create dicts with: states (index[0]) hillary votes (index[2]) donald votes (index[5])
result_votes_2016 = {}

for entry in states_data:
        state = entry[0]
        hillary_votes = entry[2]
        trump_votes = entry[5]
        
        result_votes_2016[state] = {
        "Hillary Clinton": hillary_votes,
        "Donald Trump": trump_votes
    }

#print(result_votes_2016)

# %%
# dataframe: states as indexes, percentages are saved as strings!

df_results_2016 = pd.DataFrame.from_dict(result_votes_2016, orient='index')
df_results_2016.index.name = 'State'
df_results_2016.columns = ['Hillary Clinton', 'Donald Trump']

# %%
# scraping for total percentages 2016

values = soup.find_all('th', style="text-align:right")
total_values_2016 = []

for th in values:
    text = th.get_text(strip=True)  
    if "%" in text: 
        total_values_2016.append(text)
total_values_2016 = total_values_2016[:2]

total_values_2016
# Out:
# ['48.18%', '46.09%']

# %%
# adding total votes as last row 

df_results_2016 = pd.DataFrame.from_dict(result_votes_2016, orient='index')

df_results_2016.index.name = 'State'
df_results_2016.columns = ['Hillary Clinton', 'Donald Trump']
total_votes = ['48.18%', '46.09%']
df_results_2016.loc['National'] = total_values_2016

#print(df_results_2016)

# %%
df_results_2016.index.value_counts().sum()
# Out:
# 57

# %%
# results 2020

url = "https://en.m.wikipedia.org/wiki/2020_United_States_presidential_election#Results"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup2 = BeautifulSoup(response.content)
table2 = soup2.find('div', style='overflow:auto')

# %%
# all percentages & states

table_list2 = []
for td in table2.find_all('td'):
        table_list2.append(td.text.strip())

# %%
for index, element in enumerate(table_list2):
    index, element

# %%
# creating sublists with state as first index
states_data2 = []
current_state2 = []

for element in table_list2:
    if re.search(r'[a-zA-Z]', element):  
        if current_state2:
            states_data2.append(current_state2)
        current_state2 = [element]  
    else:
        current_state2.append(element)
if current_state2:
    states_data2.append(current_state2)

# %%
#filtering state, b votes & d votes, save in dict

result_votes_2020 = {}

for entry in states_data2:
    if len(entry) > 5:
        state = entry[0]
        biden_votes = entry[2]
        trump_votes = entry[5]
        
    result_votes_2020[state] = {
        "Joseph Biden": biden_votes,
        "Donald Trump": trump_votes
    }
#print(result_votes_2020)

# %%
# scraping for total percentages

values2 = soup2.find_all('th', style="text-align:right")
percent_values2 = []
for th in values2:
    text = th.get_text(strip=True)  
    if "%" in text: 
        percent_values2.append(text)
total_percentage_2020 = percent_values2[:2]

total_percentage_2020
# Out:
# ['51.31%', '46.85%']

# %%
df_results_2020 = pd.DataFrame.from_dict(result_votes_2020, orient='index')

df_results_2020.index.name = 'State'
df_results_2020.columns = ['Joseph Biden', 'Donald Trump']
df_results_2020 = df_results_2020.drop(['[o]', '[p]'], axis=0)

df_results_2020.loc['National'] = total_percentage_2020
#print(df_results_2020)

# %%
df_results_2020.value_counts().sum()
# Out:
# 57

# %%
#df_results_2016.to_csv("df_results_2016.csv")

# %%
#df_results_2020.to_csv("df_results_2020.csv")

# %%
# function table scraping 

import requests
from bs4 import BeautifulSoup
import re
import pandas as pd

def table_scraper(year):
    result_votes_year = {} 
    response = requests.get(f"https://en.wikipedia.org/wiki/{year}_United_States_presidential_election#Results_by_state")
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('div', style='overflow:auto')                                      # find table
    if table is None:
        print(f"no results found for year: {year}.")
        return None
    table_list = [td.text.strip() for td in table.find_all('td')]                        # loop trough tables list and get td tags
    states_data = []                                                                     # create list with numbers by states                                                                
    current_state = []   
    for element in table_list:
        if re.search(r'[a-zA-Z]', element):                                              # look for values with letters (states)
            if current_state:
                states_data.append(current_state)                                        # grouping states data into sublists   
            current_state = [element]  
        else:
            current_state.append(element)     
    if current_state:
        states_data.append(current_state)
    result_votes_year = {                                                              # create with dict with indexes
    entry[0]: {
        "Democratic Candidate": entry[2],
        "Republican Candidate": entry[5]
    }
    for entry in states_data if len(entry) > 5 }                                       # create data frame
    df_results_year = pd.DataFrame.from_dict(result_votes_year, orient='index')
    df_results_year.index.name = 'State'
    df_results_year.columns = ['Democratic Candidate', 'Republican Candidate']

    # comprehension to get national votes 
    df_results_year.loc['National'] = [value for value in (th.get_text(strip=True) for th in soup.find_all('th', style="text-align:right") if "%" in th.get_text(strip=True)) if value != '%'][:2]
    
    return df_results_year

# %%
table_scraper(2016)
# Out:
#                                                   Democratic Candidate  \
# State
# Alabama                                                         34.36%
# Alaska                                                          36.55%
# Arizona                                                         44.58%
# Arkansas                                                        33.65%
# California                                                      61.73%
# Colorado                                                        48.16%
# Connecticut                                                     54.57%
# Delaware                                                        53.09%
# District of Columbia                                            90.86%
# Florida                                                         47.82%
# Georgia                                                         45.64%
# Hawaii                                                          62.22%
# Idaho                                                           27.49%
# Illinois                                                        55.83%
# Indiana                                                         37.77%
# Iowa                                                            41.74%
# Kansas                                                          36.05%
# Kentucky                                                        32.68%
# Louisiana                                                       38.45%
# Maine †                                                         47.83%
# ME-1Tooltip Maine's 1st congressional district                  53.96%
# ME-2Tooltip Maine's 2nd congressional district                  40.98%
# Maryland                                                        60.33%
# Massachusetts                                                   60.01%
# Michigan                                                        47.27%
# Minnesota                                                       46.44%
# Mississippi                                                     40.06%
# Missouri                                                        38.14%
# Montana                                                         35.75%
# Nebraska †                                                      33.70%
# NE-1Tooltip Nebraska's 1st congressional district               35.46%
# NE-2Tooltip Nebraska's 2nd congressional district               44.92%
# NE-3Tooltip Nebraska's 3rd congressional district               19.73%
# Nevada                                                          47.92%
# New Hampshire                                                   46.98%
# New Jersey                                                      55.45%
# New Mexico                                                      48.26%
# New York                                                        59.01%
# North Carolina                                                  46.17%
# North Dakota                                                    27.23%
# Ohio                                                            43.56%
# Oklahoma                                                        28.93%
# Oregon                                                          50.07%
# Pennsylvania                                                    47.46%
# Rhode Island                                                    54.41%
# South Carolina                                                  40.67%
# South Dakota                                                    31.74%
# Tennessee                                                       34.72%
# Texas                                                           43.24%
# Utah                                                            27.46%
# Vermont                                                         56.68%
# Virginia                                                        49.73%
# Washington                                                      52.54%
# West Virginia                                                   26.43%
# Wisconsin                                                       46.45%
# Wyoming                                                         21.88%
#
#                                                   Republican Candidate
# State
# Alabama                                                         62.08%
# Alaska                                                          51.28%
# Arizona                                                         48.08%
# Arkansas                                                        60.57%
# California                                                      31.62%
# Colorado                                                        43.25%
# Connecticut                                                     40.93%
# Delaware                                                        41.72%
# District of Columbia                                             4.09%
# Florida                                                         49.02%
# Georgia                                                         50.77%
# Hawaii                                                          30.03%
# Idaho                                                           59.26%
# Illinois                                                        38.76%
# Indiana                                                         56.94%
# Iowa                                                            51.15%
# Kansas                                                          56.65%
# Kentucky                                                        62.52%
# Louisiana                                                       58.09%
# Maine †                                                         44.87%
# ME-1Tooltip Maine's 1st congressional district                  39.15%
# ME-2Tooltip Maine's 2nd congressional district                  51.26%
# Maryland                                                        33.91%
# Massachusetts                                                   32.81%
# Michigan                                                        47.50%
# Minnesota                                                       44.92%
# Mississippi                                                     57.86%
# Missouri                                                        56.77%
# Montana                                                         56.17%
# Nebraska †                                                      58.75%
# NE-1Tooltip Nebraska's 1st congressional district               56.18%
# NE-2Tooltip Nebraska's 2nd congressional district               47.16%
# NE-3Tooltip Nebraska's 3rd congressional district               73.92%
# Nevada                                                          45.50%
# New Hampshire                                                   46.61%
# New Jersey                                                      41.35%
# New Mexico                                                      40.04%
# New York                                                        36.52%
# North Carolina                                                  49.83%
# North Dakota                                                    62.96%
# Ohio                                                            51.69%
# Oklahoma                                                        65.32%
# Oregon                                                          39.09%
# Pennsylvania                                                    48.18%
# Rhode Island                                                    38.90%
# South Carolina                                                  54.94%
# South Dakota                                                    61.53%
# Tennessee                                                       60.72%
# Texas                                                           52.23%
# Utah                                                            45.54%
# Vermont                                                         30.27%
# Virginia                                                        44.41%
# Washington                                                      36.83%
# West Virginia                                                   68.50%
# Wisconsin                                                       47.22%
# Wyoming                                                         68.17%

# %%
table_scraper(2020)
# Out:
#                                                   Democratic Candidate  \
# State
# Alabama                                                         36.57%
# [o]                                                              3,947
# Alaska                                                          42.77%
# [p]                                                              6,904
# Arizona                                                         49.36%
# Arkansas                                                        34.78%
# California                                                      63.48%
# Colorado                                                        55.40%
# Connecticut                                                     59.26%
# Delaware                                                        58.74%
# District of Columbia                                            92.15%
# Florida                                                         47.86%
# Georgia                                                         49.47%
# Hawaii                                                          63.73%
# Idaho                                                           33.07%
# Illinois                                                        57.54%
# Indiana                                                         40.96%
# Iowa                                                            44.89%
# Kansas                                                          41.51%
# Kentucky                                                        36.15%
# Louisiana                                                       39.85%
# Maine †                                                         53.09%
# ME-1Tooltip Maine's 1st congressional district                  60.11%
# ME-2Tooltip Maine's 2nd congressional district                  44.82%
# Maryland                                                        65.36%
# Massachusetts                                                   65.60%
# Michigan                                                        50.62%
# Minnesota                                                       52.40%
# Mississippi                                                     41.06%
# Missouri                                                        41.41%
# Montana                                                         40.55%
# Nebraska †                                                      39.17%
# NE-1Tooltip Nebraska's 1st congressional district               41.09%
# NE-2Tooltip Nebraska's 2nd congressional district               51.95%
# NE-3Tooltip Nebraska's 3rd congressional district               22.34%
# Nevada[q]                                                       50.06%
# New Hampshire                                                   52.71%
# New Jersey[r]                                                   57.33%
# New Mexico                                                      54.29%
# New York                                                        60.87%
# North Carolina                                                  48.59%
# North Dakota                                                    31.78%
# Ohio                                                            45.24%
# Oklahoma                                                        32.29%
# Oregon                                                          56.45%
# Pennsylvania                                                    49.85%
# Rhode Island                                                    59.39%
# South Carolina                                                  43.43%
# South Dakota                                                    35.61%
# Tennessee                                                       37.45%
# Texas[s]                                                        46.48%
# Utah                                                            37.65%
# Vermont                                                         66.09%
# Virginia                                                        54.11%
# Washington                                                      57.97%
# West Virginia                                                   29.69%
# Wisconsin                                                       49.45%
# Wyoming                                                         26.55%
#
#                                                   Republican Candidate
# State
# Alabama                                                         62.03%
# [o]                                                           −120,068
# Alaska                                                          52.83%
# [p]                                                            −36,173
# Arizona                                                         49.06%
# Arkansas                                                        62.40%
# California                                                      34.32%
# Colorado                                                        41.90%
# Connecticut                                                     39.19%
# Delaware                                                        39.77%
# District of Columbia                                             5.40%
# Florida                                                         51.22%
# Georgia                                                         49.24%
# Hawaii                                                          34.27%
# Idaho                                                           63.84%
# Illinois                                                        40.55%
# Indiana                                                         57.03%
# Iowa                                                            53.09%
# Kansas                                                          56.14%
# Kentucky                                                        62.09%
# Louisiana                                                       58.46%
# Maine †                                                         44.02%
# ME-1Tooltip Maine's 1st congressional district                  37.02%
# ME-2Tooltip Maine's 2nd congressional district                  52.26%
# Maryland                                                        32.15%
# Massachusetts                                                   32.14%
# Michigan                                                        47.84%
# Minnesota                                                       45.28%
# Mississippi                                                     57.60%
# Missouri                                                        56.80%
# Montana                                                         56.92%
# Nebraska †                                                      58.22%
# NE-1Tooltip Nebraska's 1st congressional district               56.01%
# NE-2Tooltip Nebraska's 2nd congressional district               45.45%
# NE-3Tooltip Nebraska's 3rd congressional district               75.36%
# Nevada[q]                                                       47.67%
# New Hampshire                                                   45.36%
# New Jersey[r]                                                   41.40%
# New Mexico                                                      43.50%
# New York                                                        37.74%
# North Carolina                                                  49.93%
# North Dakota                                                    65.12%
# Ohio                                                            53.27%
# Oklahoma                                                        65.37%
# Oregon                                                          40.37%
# Pennsylvania                                                    48.69%
# Rhode Island                                                    38.61%
# South Carolina                                                  55.11%
# South Dakota                                                    61.77%
# Tennessee                                                       60.66%
# Texas[s]                                                        52.06%
# Utah                                                            58.13%
# Vermont                                                         30.67%
# Virginia                                                        44.00%
# Washington                                                      38.77%
# West Virginia                                                   68.62%
# Wisconsin                                                       48.82%
# Wyoming                                                         69.94%

# %%
# function works with "National votes" for 2016 & 2020
# without "National votes" for 2012
# also works for 2008 but takes the number of votes not percentages because the table is slightly different
