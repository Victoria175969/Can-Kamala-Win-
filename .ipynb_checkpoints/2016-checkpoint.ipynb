# %%
import pandas as pd

url = "/Users/alexkabanovsky/Downloads/pres_pollaverages_1968-2016.csv"
df = pd.read_csv(url)

# %%
df.drop(columns = ['_nat_shortpoly_combpoly_weight', '_shortpoly_combpoly_weight','_nonlinear_polynomial_degree', '_attenuate_endpoints', '_out_of_state_house_discount','_state_trendline_weight','_state_houseeffects_weight', '_numloops', '_defaultbasetime','_minpoints'],  axis =1, inplace=True)

# %%
df.drop(columns = ['_medpoly2', 'trend_medpoly2','_shortpoly0', 'trend_shortpoly0', 'sum_weight_medium', 'sum_weight_short', 'sum_influence', 'sum_nat_influence','_house_effects_multiplier'],  axis =1, inplace=True)

# %%
df.drop(['timestamp','comment', 'last_enddate'],  axis =1, inplace=True)
df
# Out:
#         cycle     state  modeldate        candidate_name  candidate_id  \
# 0        2016   Alabama   3/3/2016          Donald Trump          9849
# 1        2016    Alaska   3/3/2016          Donald Trump          9849
# 2        2016   Arizona   3/3/2016          Donald Trump          9849
# 3        2016  Colorado   3/3/2016          Donald Trump          9849
# 4        2016   Florida   3/3/2016          Donald Trump          9849
# ...       ...       ...        ...                   ...           ...
# 217468   1968  National  11/4/1968  Hubert Humphrey, Jr.        680002
# 217469   1968  National  11/4/1968      Richard M. Nixon        680001
# 217470   1968  National  11/5/1968        George Wallace        680003
# 217471   1968  National  11/5/1968  Hubert Humphrey, Jr.        680002
# 217472   1968  National  11/5/1968      Richard M. Nixon        680001
#
#         pct_estimate  pct_trend_adjusted election_date  election_qdate  \
# 0           70.11138            68.63747     11/8/2016             448
# 1           51.63014            49.68174     11/8/2016             448
# 2           44.00000            41.02212     11/8/2016             448
# 3           45.95150            43.51193     11/8/2016             448
# 4           46.54603            44.68674     11/8/2016             448
# ...              ...                 ...           ...             ...
# 217468      39.06675            40.46579     11/5/1968             407
# 217469      47.72081            47.83623     11/5/1968             407
# 217470      15.00200            14.39688     11/5/1968             407
# 217471      39.06675            40.46579     11/5/1968             407
# 217472      47.72081            47.83623     11/5/1968             407
#
#         last_qdate
# 0               66
# 1               63
# 2               30
# 3              113
# 4              110
# ...            ...
# 217468         402
# 217469         402
# 217470         402
# 217471         402
# 217472         402
#
# [217473 rows x 10 columns]

# %%
import datetime as dt
df['modeldate'] = pd.to_datetime(df['modeldate'])
start_date = dt.datetime(2016, 7, 1)
end_date = dt.datetime(2016, 11, 9)

index_names = df[(df['modeldate'] < start_date) | (df['modeldate'] > end_date)].index
  
df.drop(index_names, inplace = True)
df.dropna(how="any", inplace=True)
df
# Out:
#        cycle          state  modeldate          candidate_name  candidate_id  \
# 9392    2016         Alaska 2016-07-01            Gary Johnson          9459
# 9393    2016        Arizona 2016-07-01            Gary Johnson          9459
# 9394    2016       Arkansas 2016-07-01            Gary Johnson          9459
# 9395    2016     California 2016-07-01            Gary Johnson          9459
# 9396    2016       Colorado 2016-07-01            Gary Johnson          9459
# ...      ...            ...        ...                     ...           ...
# 28549   2016       Virginia 2016-11-08  Hillary Rodham Clinton          9207
# 28550   2016     Washington 2016-11-08  Hillary Rodham Clinton          9207
# 28551   2016  West Virginia 2016-11-08  Hillary Rodham Clinton          9207
# 28552   2016      Wisconsin 2016-11-08  Hillary Rodham Clinton          9207
# 28553   2016        Wyoming 2016-11-08  Hillary Rodham Clinton          9207
#
#        pct_estimate  pct_trend_adjusted election_date  election_qdate  \
# 9392      15.050810           14.386830     11/8/2016             448
# 9393       7.272027            7.246434     11/8/2016             448
# 9394       8.005040            7.681001     11/8/2016             448
# 9395       4.463887            4.363229     11/8/2016             448
# 9396       4.171414            4.000523     11/8/2016             448
# ...             ...                 ...           ...             ...
# 28549     47.267190           47.285300     11/8/2016             448
# 28550     50.271080           50.272250     11/8/2016             448
# 28551     28.617830           28.594330     11/8/2016             448
# 28552     46.565560           46.594750     11/8/2016             448
# 28553     22.079570           22.159530     11/8/2016             448
#
#        last_qdate
# 9392          244
# 9393          242
# 9394          247
# 9395          236
# 9396          249
# ...           ...
# 28549         444
# 28550         445
# 28551         444
# 28552         445
# 28553         444
#
# [19162 rows x 10 columns]

# %%
name = df['candidate_name'].unique()
print(name)
# Out:
# ['Gary Johnson' 'Donald Trump' 'Hillary Rodham Clinton']

# %%
swing_states = ["Arizona", "Georgia", "Michigan", "Nevada", "North Carolina", "Pennsylvania", "Wisconsin"]

# %%
large_states = ["California", "Texas"]

# %%
individual_swing_states = ["Pennsylvania", "Wisconsin"]

# %%
individual_swing_states2 = ["Georgia", "Nevada"]

# %%
df.loc[:,['state', 'candidate_name', 'pct_estimate']]
df
# Out:
#        cycle          state  modeldate          candidate_name  candidate_id  \
# 9392    2016         Alaska 2016-07-01            Gary Johnson          9459
# 9393    2016        Arizona 2016-07-01            Gary Johnson          9459
# 9394    2016       Arkansas 2016-07-01            Gary Johnson          9459
# 9395    2016     California 2016-07-01            Gary Johnson          9459
# 9396    2016       Colorado 2016-07-01            Gary Johnson          9459
# ...      ...            ...        ...                     ...           ...
# 28549   2016       Virginia 2016-11-08  Hillary Rodham Clinton          9207
# 28550   2016     Washington 2016-11-08  Hillary Rodham Clinton          9207
# 28551   2016  West Virginia 2016-11-08  Hillary Rodham Clinton          9207
# 28552   2016      Wisconsin 2016-11-08  Hillary Rodham Clinton          9207
# 28553   2016        Wyoming 2016-11-08  Hillary Rodham Clinton          9207
#
#        pct_estimate  pct_trend_adjusted election_date  election_qdate  \
# 9392      15.050810           14.386830     11/8/2016             448
# 9393       7.272027            7.246434     11/8/2016             448
# 9394       8.005040            7.681001     11/8/2016             448
# 9395       4.463887            4.363229     11/8/2016             448
# 9396       4.171414            4.000523     11/8/2016             448
# ...             ...                 ...           ...             ...
# 28549     47.267190           47.285300     11/8/2016             448
# 28550     50.271080           50.272250     11/8/2016             448
# 28551     28.617830           28.594330     11/8/2016             448
# 28552     46.565560           46.594750     11/8/2016             448
# 28553     22.079570           22.159530     11/8/2016             448
#
#        last_qdate
# 9392          244
# 9393          242
# 9394          247
# 9395          236
# 9396          249
# ...           ...
# 28549         444
# 28550         445
# 28551         444
# 28552         445
# 28553         444
#
# [19162 rows x 10 columns]

# %%
df.drop(['cycle','candidate_id', 'election_date', 'election_qdate',	'last_qdate'],  axis =1, inplace=True)
df
# Out:
#                state  modeldate          candidate_name  pct_estimate  \
# 9392          Alaska 2016-07-01            Gary Johnson     15.050810
# 9393         Arizona 2016-07-01            Gary Johnson      7.272027
# 9394        Arkansas 2016-07-01            Gary Johnson      8.005040
# 9395      California 2016-07-01            Gary Johnson      4.463887
# 9396        Colorado 2016-07-01            Gary Johnson      4.171414
# ...              ...        ...                     ...           ...
# 28549       Virginia 2016-11-08  Hillary Rodham Clinton     47.267190
# 28550     Washington 2016-11-08  Hillary Rodham Clinton     50.271080
# 28551  West Virginia 2016-11-08  Hillary Rodham Clinton     28.617830
# 28552      Wisconsin 2016-11-08  Hillary Rodham Clinton     46.565560
# 28553        Wyoming 2016-11-08  Hillary Rodham Clinton     22.079570
#
#        pct_trend_adjusted
# 9392            14.386830
# 9393             7.246434
# 9394             7.681001
# 9395             4.363229
# 9396             4.000523
# ...                   ...
# 28549           47.285300
# 28550           50.272250
# 28551           28.594330
# 28552           46.594750
# 28553           22.159530
#
# [19162 rows x 5 columns]

# %%
df = df[df['candidate_name'] != 'Gary Johnson']
df
# Out:
#                state  modeldate          candidate_name  pct_estimate  \
# 9418         Alabama 2016-07-01            Donald Trump      70.05815
# 9419          Alaska 2016-07-01            Donald Trump      45.95880
# 9420         Arizona 2016-07-01            Donald Trump      41.87172
# 9421        Arkansas 2016-07-01            Donald Trump      47.00000
# 9422      California 2016-07-01            Donald Trump      33.19515
# ...              ...        ...                     ...           ...
# 28549       Virginia 2016-11-08  Hillary Rodham Clinton      47.26719
# 28550     Washington 2016-11-08  Hillary Rodham Clinton      50.27108
# 28551  West Virginia 2016-11-08  Hillary Rodham Clinton      28.61783
# 28552      Wisconsin 2016-11-08  Hillary Rodham Clinton      46.56556
# 28553        Wyoming 2016-11-08  Hillary Rodham Clinton      22.07957
#
#        pct_trend_adjusted
# 9418             67.22025
# 9419             44.55957
# 9420             41.24359
# 9421             47.36731
# 9422             31.96065
# ...                   ...
# 28549            47.28530
# 28550            50.27225
# 28551            28.59433
# 28552            46.59475
# 28553            22.15953
#
# [13378 rows x 5 columns]

# %%
filtered_df = df[df['state'].isin(large_states)]
filtered_df
# Out:
#             state  modeldate          candidate_name  pct_estimate  \
# 9422   California 2016-07-01            Donald Trump      33.19515
# 9456        Texas 2016-07-01            Donald Trump      42.45778
# 9467   California 2016-07-01  Hillary Rodham Clinton      52.61412
# 9501        Texas 2016-07-01  Hillary Rodham Clinton      35.91338
# 9538   California 2016-07-02            Donald Trump      32.20488
# ...           ...        ...                     ...           ...
# 28377       Texas 2016-11-07  Hillary Rodham Clinton      38.62470
# 28444  California 2016-11-08            Donald Trump      32.83490
# 28489       Texas 2016-11-08            Donald Trump      48.32655
# 28501  California 2016-11-08  Hillary Rodham Clinton      54.91905
# 28546       Texas 2016-11-08  Hillary Rodham Clinton      38.62470
#
#        pct_trend_adjusted
# 9422             31.96065
# 9456             42.11520
# 9467             52.88642
# 9501             34.99324
# 9538             30.94666
# ...                   ...
# 28377            38.58099
# 28444            32.96150
# 28489            48.41615
# 28501            54.90748
# 28546            38.58099
#
# [524 rows x 5 columns]

# %%
name = df['state'].unique()
print(name)
# Out:
# ['Alabama' 'Alaska' 'Arizona' 'Arkansas' 'California' 'Colorado'
#  'Connecticut' 'Florida' 'Georgia' 'Idaho' 'Illinois' 'Indiana' 'Iowa'
#  'Kansas' 'Louisiana' 'ME-1' 'ME-2' 'Maine' 'Maryland' 'Massachusetts'
#  'Michigan' 'Minnesota' 'Mississippi' 'Missouri' 'Montana' 'National'
#  'Nevada' 'New Hampshire' 'New Jersey' 'New Mexico' 'New York'
#  'North Carolina' 'Ohio' 'Oklahoma' 'Oregon' 'Pennsylvania'
#  'South Carolina' 'Tennessee' 'Texas' 'Utah' 'Vermont' 'Virginia'
#  'Washington' 'West Virginia' 'Wisconsin' 'Kentucky' 'Delaware' 'Hawaii'
#  'Nebraska' 'North Dakota' 'Rhode Island' 'South Dakota' 'Wyoming' 'NE-1'
#  'NE-2' 'NE-3' 'District of Columbia']

# %%
state = df['state'].nunique()
print(state)
# Out:
# 57

# %%
national = df[df['state'] == 'National']
national
# Out:
#           state  modeldate          candidate_name  pct_estimate  \
# 9443   National 2016-07-01            Donald Trump      39.03957
# 9488   National 2016-07-01  Hillary Rodham Clinton      43.48644
# 9559   National 2016-07-02            Donald Trump      39.12633
# 9604   National 2016-07-02  Hillary Rodham Clinton      43.48127
# 9675   National 2016-07-03            Donald Trump      39.22176
# ...         ...        ...                     ...           ...
# 28191  National 2016-11-06  Hillary Rodham Clinton      45.73003
# 28303  National 2016-11-07            Donald Trump      41.88613
# 28360  National 2016-11-07  Hillary Rodham Clinton      45.83657
# 28472  National 2016-11-08            Donald Trump      41.88613
# 28529  National 2016-11-08  Hillary Rodham Clinton      45.83657
#
#        pct_trend_adjusted
# 9443             39.33026
# 9488             43.50499
# 9559             39.41888
# 9604             43.49147
# 9675             39.52192
# ...                   ...
# 28191            45.71924
# 28303            42.01038
# 28360            45.81397
# 28472            42.01038
# 28529            45.81397
#
# [262 rows x 5 columns]

# %%
#df.rename(columns=lambda x: x.replace('modeldate','date'), inplace=True)
#df

# %%
#df.rename(columns=lambda x: x.replace('candidate_name','name'), inplace=True)
#df

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.lineplot(data=filtered_df, x='modeldate', y='pct_estimate', hue='candidate_name', style='state', markers=True)

plt.xlabel('Model Date')
plt.ylabel('Percentage Estimate')
plt.title('Percentage Estimate over Time for Each Candidate by State')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
filtered_df2 = df[df['state'].isin(swing_states)]
filtered_df2
# Out:
#                 state  modeldate          candidate_name  pct_estimate  \
# 9420          Arizona 2016-07-01            Donald Trump      41.87172
# 9426          Georgia 2016-07-01            Donald Trump      45.49901
# 9438         Michigan 2016-07-01            Donald Trump      35.58404
# 9444           Nevada 2016-07-01            Donald Trump      45.40713
# 9449   North Carolina 2016-07-01            Donald Trump      41.15075
# ...               ...        ...                     ...           ...
# 28521        Michigan 2016-11-08  Hillary Rodham Clinton      45.66772
# 28531          Nevada 2016-11-08  Hillary Rodham Clinton      44.89117
# 28536  North Carolina 2016-11-08  Hillary Rodham Clinton      46.44271
# 28541    Pennsylvania 2016-11-08  Hillary Rodham Clinton      46.50476
# 28552       Wisconsin 2016-11-08  Hillary Rodham Clinton      46.56556
#
#        pct_trend_adjusted
# 9420             41.24359
# 9426             43.90436
# 9438             34.59080
# 9444             43.72832
# 9449             41.54263
# ...                   ...
# 28521            45.63504
# 28531            44.86731
# 28536            46.44571
# 28541            46.48753
# 28552            46.59475
#
# [1834 rows x 5 columns]

# %%
individual = df[df['state'].isin(individual_swing_states)]
df
# Out:
#                state  modeldate          candidate_name  pct_estimate  \
# 9418         Alabama 2016-07-01            Donald Trump      70.05815
# 9419          Alaska 2016-07-01            Donald Trump      45.95880
# 9420         Arizona 2016-07-01            Donald Trump      41.87172
# 9421        Arkansas 2016-07-01            Donald Trump      47.00000
# 9422      California 2016-07-01            Donald Trump      33.19515
# ...              ...        ...                     ...           ...
# 28549       Virginia 2016-11-08  Hillary Rodham Clinton      47.26719
# 28550     Washington 2016-11-08  Hillary Rodham Clinton      50.27108
# 28551  West Virginia 2016-11-08  Hillary Rodham Clinton      28.61783
# 28552      Wisconsin 2016-11-08  Hillary Rodham Clinton      46.56556
# 28553        Wyoming 2016-11-08  Hillary Rodham Clinton      22.07957
#
#        pct_trend_adjusted
# 9418             67.22025
# 9419             44.55957
# 9420             41.24359
# 9421             47.36731
# 9422             31.96065
# ...                   ...
# 28549            47.28530
# 28550            50.27225
# 28551            28.59433
# 28552            46.59475
# 28553            22.15953
#
# [13378 rows x 5 columns]

# %%
individual2 = df[df['state'].isin(individual_swing_states2)]
df
# Out:
#                state  modeldate          candidate_name  pct_estimate  \
# 9418         Alabama 2016-07-01            Donald Trump      70.05815
# 9419          Alaska 2016-07-01            Donald Trump      45.95880
# 9420         Arizona 2016-07-01            Donald Trump      41.87172
# 9421        Arkansas 2016-07-01            Donald Trump      47.00000
# 9422      California 2016-07-01            Donald Trump      33.19515
# ...              ...        ...                     ...           ...
# 28549       Virginia 2016-11-08  Hillary Rodham Clinton      47.26719
# 28550     Washington 2016-11-08  Hillary Rodham Clinton      50.27108
# 28551  West Virginia 2016-11-08  Hillary Rodham Clinton      28.61783
# 28552      Wisconsin 2016-11-08  Hillary Rodham Clinton      46.56556
# 28553        Wyoming 2016-11-08  Hillary Rodham Clinton      22.07957
#
#        pct_trend_adjusted
# 9418             67.22025
# 9419             44.55957
# 9420             41.24359
# 9421             47.36731
# 9422             31.96065
# ...                   ...
# 28549            47.28530
# 28550            50.27225
# 28551            28.59433
# 28552            46.59475
# 28553            22.15953
#
# [13378 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.lineplot(data=individual, x='modeldate', y='pct_estimate', hue='candidate_name', style='state', markers=True)

plt.xlabel('Date')
plt.ylabel('Percentage Estimate')
plt.title('Percentage Estimate over Time for Each Candidate by State')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.lineplot(data=individual2, x='modeldate', y='pct_estimate', hue='candidate_name', style='state', markers=True)

plt.xlabel('Date')
plt.ylabel('Percentage Estimate')
plt.title('Percentage Estimate over Time for Each Candidate by State')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
#Scott Walker is a nice guy, but not presidential material. 
#Wisconsin is in turmoil, borrowing to the hilt, and doing poorly in jobs etc. - 26 July 2015

# %%
url = "/Users/alexkabanovsky/Downloads/presidential_poll_averages_2020.csv"
df2020 = pd.read_csv(url)
df2020
# Out:
#        cycle          state  modeldate       candidate_name  pct_estimate  \
# 0       2020        Wyoming  11/3/2020  Joseph R. Biden Jr.      30.81486
# 1       2020      Wisconsin  11/3/2020  Joseph R. Biden Jr.      52.12642
# 2       2020  West Virginia  11/3/2020  Joseph R. Biden Jr.      33.49125
# 3       2020     Washington  11/3/2020  Joseph R. Biden Jr.      59.34201
# 4       2020       Virginia  11/3/2020  Joseph R. Biden Jr.      53.74120
# ...      ...            ...        ...                  ...           ...
# 29080   2020    Connecticut  2/27/2020         Donald Trump      33.66370
# 29081   2020       Colorado  2/27/2020         Donald Trump      44.27899
# 29082   2020     California  2/27/2020         Donald Trump      34.66504
# 29083   2020        Arizona  2/27/2020         Donald Trump      47.79450
# 29084   2020        Alabama  2/27/2020         Donald Trump      59.15000
#
#        pct_trend_adjusted
# 0                30.82599
# 1                52.09584
# 2                33.51517
# 3                59.39408
# 4                53.72101
# ...                   ...
# 29080            34.58325
# 29081            44.07662
# 29082            34.69761
# 29083            48.07208
# 29084            59.14228
#
# [29085 rows x 6 columns]

# %%
df2020.drop(['cycle'],  axis =1, inplace=True)
df2020
# Out:
#                state  modeldate       candidate_name  pct_estimate  \
# 0            Wyoming  11/3/2020  Joseph R. Biden Jr.      30.81486
# 1          Wisconsin  11/3/2020  Joseph R. Biden Jr.      52.12642
# 2      West Virginia  11/3/2020  Joseph R. Biden Jr.      33.49125
# 3         Washington  11/3/2020  Joseph R. Biden Jr.      59.34201
# 4           Virginia  11/3/2020  Joseph R. Biden Jr.      53.74120
# ...              ...        ...                  ...           ...
# 29080    Connecticut  2/27/2020         Donald Trump      33.66370
# 29081       Colorado  2/27/2020         Donald Trump      44.27899
# 29082     California  2/27/2020         Donald Trump      34.66504
# 29083        Arizona  2/27/2020         Donald Trump      47.79450
# 29084        Alabama  2/27/2020         Donald Trump      59.15000
#
#        pct_trend_adjusted
# 0                30.82599
# 1                52.09584
# 2                33.51517
# 3                59.39408
# 4                53.72101
# ...                   ...
# 29080            34.58325
# 29081            44.07662
# 29082            34.69761
# 29083            48.07208
# 29084            59.14228
#
# [29085 rows x 5 columns]

# %%
import datetime as dt
df2020['modeldate'] = pd.to_datetime(df2020['modeldate'])
start_date = dt.datetime(2020, 7, 1)
end_date = dt.datetime(2020, 11, 3)

index_names = df2020[(df2020['modeldate'] < start_date) | (df2020['modeldate'] > end_date)].index
  
df2020.drop(index_names, inplace = True)
df2020.dropna(how="any", inplace=True)
df2020
# Out:
#                state  modeldate       candidate_name  pct_estimate  \
# 0            Wyoming 2020-11-03  Joseph R. Biden Jr.      30.81486
# 1          Wisconsin 2020-11-03  Joseph R. Biden Jr.      52.12642
# 2      West Virginia 2020-11-03  Joseph R. Biden Jr.      33.49125
# 3         Washington 2020-11-03  Joseph R. Biden Jr.      59.34201
# 4           Virginia 2020-11-03  Joseph R. Biden Jr.      53.74120
# ...              ...        ...                  ...           ...
# 19784       Colorado 2020-07-01         Donald Trump      39.23602
# 19785     California 2020-07-01         Donald Trump      33.08887
# 19786       Arkansas 2020-07-01         Donald Trump      47.01842
# 19787        Arizona 2020-07-01         Donald Trump      44.51127
# 19788        Alabama 2020-07-01         Donald Trump      56.40528
#
#        pct_trend_adjusted
# 0                30.82599
# 1                52.09584
# 2                33.51517
# 3                59.39408
# 4                53.72101
# ...                   ...
# 19784            37.92071
# 19785            31.54198
# 19786            46.86518
# 19787            44.29824
# 19788            54.78703
#
# [19789 rows x 5 columns]

# %%
df2020 = df2020[df2020['candidate_name'] != 'Convention Bounce for Joseph R. Biden Jr.']
df2020
df2020 = df2020[df2020['candidate_name'] != 'Convention Bounce for Donald Trump']
df2020
# Out:
#                state  modeldate       candidate_name  pct_estimate  \
# 0            Wyoming 2020-11-03  Joseph R. Biden Jr.      30.81486
# 1          Wisconsin 2020-11-03  Joseph R. Biden Jr.      52.12642
# 2      West Virginia 2020-11-03  Joseph R. Biden Jr.      33.49125
# 3         Washington 2020-11-03  Joseph R. Biden Jr.      59.34201
# 4           Virginia 2020-11-03  Joseph R. Biden Jr.      53.74120
# ...              ...        ...                  ...           ...
# 19784       Colorado 2020-07-01         Donald Trump      39.23602
# 19785     California 2020-07-01         Donald Trump      33.08887
# 19786       Arkansas 2020-07-01         Donald Trump      47.01842
# 19787        Arizona 2020-07-01         Donald Trump      44.51127
# 19788        Alabama 2020-07-01         Donald Trump      56.40528
#
#        pct_trend_adjusted
# 0                30.82599
# 1                52.09584
# 2                33.51517
# 3                59.39408
# 4                53.72101
# ...                   ...
# 19784            37.92071
# 19785            31.54198
# 19786            46.86518
# 19787            44.29824
# 19788            54.78703
#
# [12176 rows x 5 columns]

# %%
df2020['modeldate'] = pd.to_datetime(df2020['modeldate'])
df_sorted2020 = df2020.sort_values(by='modeldate', ascending=True)

df_sorted2020
# Out:
#              state  modeldate       candidate_name  pct_estimate  \
# 19788      Alabama 2020-07-01         Donald Trump      56.40528
# 19728     Missouri 2020-07-01  Joseph R. Biden Jr.      44.52657
# 19729  Mississippi 2020-07-01  Joseph R. Biden Jr.      40.45329
# 19730    Minnesota 2020-07-01  Joseph R. Biden Jr.      53.60623
# 19731     Michigan 2020-07-01  Joseph R. Biden Jr.      49.88876
# ...            ...        ...                  ...           ...
# 80        National 2020-11-03         Donald Trump      43.39262
# 81            NE-2 2020-11-03         Donald Trump      46.08874
# 82            NE-1 2020-11-03         Donald Trump      49.43981
# 56         Wyoming 2020-11-03         Donald Trump      61.97429
# 0          Wyoming 2020-11-03  Joseph R. Biden Jr.      30.81486
#
#        pct_trend_adjusted
# 19788            54.78703
# 19728            45.12057
# 19729            41.06105
# 19730            54.36530
# 19731            50.15809
# ...                   ...
# 80               43.40869
# 81               46.21062
# 82               50.75042
# 56               62.31048
# 0                30.82599
#
# [12176 rows x 5 columns]

# %%
large_states = ["California", "Texas"]

# %%
filtered_df2020 = df2020[df2020['state'].isin(large_states)]
filtered_df2020
# Out:
#             state  modeldate       candidate_name  pct_estimate  \
# 7           Texas 2020-11-03  Joseph R. Biden Jr.      47.46643
# 51     California 2020-11-03  Joseph R. Biden Jr.      61.62906
# 63          Texas 2020-11-03         Donald Trump      48.57118
# 107    California 2020-11-03         Donald Trump      32.28521
# 231         Texas 2020-11-02  Joseph R. Biden Jr.      47.46643
# ...           ...        ...                  ...           ...
# 19703  California 2020-07-02         Donald Trump      33.07095
# 19712       Texas 2020-07-01  Joseph R. Biden Jr.      45.71981
# 19744  California 2020-07-01  Joseph R. Biden Jr.      60.31712
# 19753       Texas 2020-07-01         Donald Trump      47.65641
# 19785  California 2020-07-01         Donald Trump      33.08887
#
#        pct_trend_adjusted
# 7                47.44781
# 51               61.62459
# 63               48.58794
# 107              32.43615
# 231              47.44781
# ...                   ...
# 19703            31.57598
# 19712            46.53586
# 19744            61.24839
# 19753            46.81166
# 19785            31.54198
#
# [504 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.lineplot(data=filtered_df2020, x='modeldate', y='pct_estimate', hue='candidate_name', style='state', markers=True)

plt.xlabel('Date')
plt.ylabel('Percentage Estimate')
plt.title('Percentage Estimate over Time for Each Candidate by State')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
swing_states2020 = ["Arizona", "Georgia", "Michigan", "Nevada", "North Carolina", "Pennsylvania", "Wisconsin"]

# %%
individual_swing_states2020 = ["Pennsylvania", "Wisconsin"]

# %%
individual2020 = df2020[df2020['state'].isin(swing_states2020)]
df2020
# Out:
#                state  modeldate       candidate_name  pct_estimate  \
# 0            Wyoming 2020-11-03  Joseph R. Biden Jr.      30.81486
# 1          Wisconsin 2020-11-03  Joseph R. Biden Jr.      52.12642
# 2      West Virginia 2020-11-03  Joseph R. Biden Jr.      33.49125
# 3         Washington 2020-11-03  Joseph R. Biden Jr.      59.34201
# 4           Virginia 2020-11-03  Joseph R. Biden Jr.      53.74120
# ...              ...        ...                  ...           ...
# 19784       Colorado 2020-07-01         Donald Trump      39.23602
# 19785     California 2020-07-01         Donald Trump      33.08887
# 19786       Arkansas 2020-07-01         Donald Trump      47.01842
# 19787        Arizona 2020-07-01         Donald Trump      44.51127
# 19788        Alabama 2020-07-01         Donald Trump      56.40528
#
#        pct_trend_adjusted
# 0                30.82599
# 1                52.09584
# 2                33.51517
# 3                59.39408
# 4                53.72101
# ...                   ...
# 19784            37.92071
# 19785            31.54198
# 19786            46.86518
# 19787            44.29824
# 19788            54.78703
#
# [12176 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as snsplt.figure(figsize=(12, 8))

sns.lineplot(individual2020, x='modeldate', y='pct_estimate', hue='candidate_name', style='state', markers=True)

plt.xlabel('Date')
plt.ylabel('Percentage Estimate')
plt.title('Percentage Estimate over Time for Each Candidate by State')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
#   Cell In[45], line 2
#     import seaborn as snsplt.figure(figsize=(12, 8))
#                             ^
# SyntaxError: invalid syntax

# %%
individual_swing_states2_2020 = ["Georgia", "Nevada"]

# %%
plt.figure(figsize=(12, 8))
sns.lineplot(individual_swing_states2_2020, x='modeldate', y='pct_estimate', hue='candidate_name', style='state', markers=True)

plt.xlabel('Date')
plt.ylabel('Percentage Estimate')
plt.title('Percentage Estimate over Time for Each Candidate by State')

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
